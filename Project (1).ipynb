# %%
import pandas as pd
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
ad = pd.read_excel("C:\\Users\\Ramamoorthy\\OneDrive\\Documents\\Data\\advertisement.xlsx")
ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        68.95  35.0     61833.90                256.09
# 1                          NaN  31.0     68441.85                193.77
# 2                        69.47  26.0     59785.94                236.50
# 3                        74.15  29.0     54806.18                245.89
# 4                        68.37  35.0     73889.99                225.58
# ...                        ...   ...          ...                   ...
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1007                     55.55  19.0     41920.79                187.95
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line            City  Gender  \
# ...

# %%
ad.dtypes
# Out:
# Daily Time Spent on Site    float64
# Age                         float64
# Area Income                 float64
# Daily Internet Usage        float64
# Ad Topic Line                object
# City                         object
# Gender                       object
# Country                      object
# Timestamp                    object
# Clicked on Ad                 int64
# dtype: object

# %%
ad.isnull().sum()
# Out:
# Daily Time Spent on Site     4
# Age                         11
# Area Income                 11
# Daily Internet Usage         4
# Ad Topic Line                0
# City                        11
# Gender                       0
# Country                     13
# Timestamp                    0
# Clicked on Ad                0
# dtype: int64

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1005 non-null   float64
#  1   Age                       998 non-null    float64
#  2   Area Income               998 non-null    float64
#  3   Daily Internet Usage      1005 non-null   float64
#  4   Ad Topic Line             1009 non-null   object
#  5   City                      998 non-null    object
#  6   Gender                    1009 non-null   object
#  7   Country                   996 non-null    object
#  8   Timestamp                 1009 non-null   object
#  9   Clicked on Ad             1009 non-null   int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 79.0+ KB

# %%
ad.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Gender', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
x=pd.unique(ad["City"])
x
# Out:
# array(['Wrightburgh', 'West Jodi', 'Davidton', 'West Terrifurt',
#        'South Manuel', nan, 'Brandonstad', 'Port Jefferybury',
#        'West Colin', 'Ramirezton', 'West Brandonton', 'West Katiefurt',
#        'North Tara', 'West William', 'New Travistown', 'Pruittmouth',
#        'Jessicastad', 'Millertown', 'Lake Nicole', 'South John',
#        'Pamelamouth', 'Harperborough', 'Port Danielleberg',
#        'West Jeremyside', 'South Cathyfurt', 'Palmerside', 'West Guybury',
#        'Phelpschester', 'Lake Melindamouth', 'Port Cassie', 'New Thomas',
#        'Johnstad', 'West Aprilport', 'Kellytown', 'Charlesport',
#        'Millerchester', 'Mackenziemouth', 'Zacharystad', 'North Joshua',
#        'Bowenview', 'Jamesberg', 'Lake Cassandraport', 'New Sharon',
#        'Johnport', 'Hamiltonfort', 'West Christopher', 'Hollandberg',
#        'Odomville', 'East Samanthashire', 'South Lauraton', 'Amandahaven',
#        'Thomasview', 'Garciaside', 'Port Sarahshire', 'Port Gregory',
# ...

# %%
ad["City"]=="nan"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1004    False
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# Name: City, Length: 1009, dtype: bool

# %%
a = ad[ad["City"].isna()]

# %%
a
# Out:
#      Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 5                       59.99  23.0     59761.56                226.74
# 11                      83.07  37.0     62491.01                230.87
# 16                      55.39  37.0     23936.86                129.41
# 20                      77.22  30.0     64802.33                224.44
# 32                      59.05  57.0     25583.29                169.23
# 64                      45.96  45.0     66281.46                141.22
# 74                      38.46  42.0     58183.04                145.98
# 84                      70.79  31.0     74535.94                184.10
# 108                     47.53  30.0     33258.09                135.18
# 122                     77.65  27.0     63274.88                212.79
# 686                     69.47  26.0     59785.94                236.50
#
#                                      Ad Topic Line City  Gender  \
# ...

# %%
pd.unique(ad["Country"])
# Out:
# array(['Tunisia', 'Nauru', 'San Marino', 'Italy', 'Iceland', 'Norway',
#        'Myanmar', 'Australia', 'Grenada', 'Ghana', 'Qatar', 'Burundi',
#        'Egypt', 'Bosnia and Herzegovina', 'Barbados', 'Spain',
#        'Palestinian Territory', 'Afghanistan',
#        'British Indian Ocean Territory (Chagos Archipelago)',
#        'Russian Federation', 'Cameroon', 'Korea', 'Tokelau', 'Monaco',
#        'Tuvalu', 'Greece', 'British Virgin Islands',
#        'Bouvet Island (Bouvetoya)', 'Peru', 'Aruba', 'Maldives',
#        'Senegal', 'Dominica', 'Luxembourg', 'Montenegro', 'Ukraine',
#        'Saint Helena', 'Liberia', nan, 'Niger', 'Turkmenistan',
#        'Sri Lanka', 'Trinidad and Tobago', 'United Kingdom',
#        'Guinea-Bissau', 'Micronesia', 'Turkey', 'Croatia', 'Israel',
#        'Svalbard & Jan Mayen Islands', 'Azerbaijan', 'Iran',
#        'Saint Vincent and the Grenadines', 'Bulgaria', 'Christmas Island',
# ...

# %%
b = ad[ad["Age"].isna()]

# %%
b
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 340                     74.38  NaN     74024.61                220.05
# 349                     37.87  NaN     56394.82                188.56
# 358                     37.45  NaN     31281.01                167.86
# 420                     72.92  NaN     69428.73                217.10
# 517                     81.51  NaN     53412.32                250.03
# 708                     76.02  NaN     73174.19                219.55
# 847                     79.51  NaN     34942.26                125.11
# 901                     36.37  NaN     47338.94                144.53
# 959                     41.35  NaN     39193.45                162.46
# 971                     70.09  NaN     54725.87                211.17
# 994                     72.88  NaN     64011.26                125.12
#
#                                   Ad Topic Line                City  Gender  \
# ...

# %%
ad=ad.fillna(method="ffill")

# %%
ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        68.95  35.0     61833.90                256.09
# 1                        68.95  31.0     68441.85                193.77
# 2                        69.47  26.0     59785.94                236.50
# 3                        74.15  29.0     54806.18                245.89
# 4                        68.37  35.0     73889.99                225.58
# ...                        ...   ...          ...                   ...
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1007                     55.55  19.0     41920.79                187.95
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line            City  Gender  \
# ...

# %%
ad = ad.fillna(method="bfill")

# %%
ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        68.95  35.0     61833.90                256.09
# 1                        68.95  31.0     68441.85                193.77
# 2                        69.47  26.0     59785.94                236.50
# 3                        74.15  29.0     54806.18                245.89
# 4                        68.37  35.0     73889.99                225.58
# ...                        ...   ...          ...                   ...
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1007                     55.55  19.0     41920.79                187.95
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line            City  Gender  \
# ...

# %%
ad.isna().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Gender                      0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
ad.to_excel("cleaned.xlsx")

# %%
ad.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Gender', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
ad.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1009.000000  1009.000000   1009.000000
# mean                  65.034916    35.941526  54907.630565
# std                   15.876290     8.757171  13430.467831
# min                   32.600000    19.000000  13996.500000
# 25%                   51.380000    29.000000  46964.110000
# 50%                   68.410000    35.000000  56986.730000
# 75%                   78.570000    42.000000  65280.160000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage  Clicked on Ad
# count           1009.000000    1009.000000
# mean             180.054252       0.501487
# std               43.855649       0.500246
# min              104.780000       0.000000
# 25%              139.010000       0.000000
# 50%              183.430000       1.000000
# 75%              218.790000       1.000000
# max              269.960000       1.000000

# %% [markdown]
# Interpretation:
# Daily Time Spent on Site : The users spent between 32 min to 91 min on the site with a mean value of 65 min , Which is quite a large amount of time.
# Age : The user age Ranges from 19 age to 61 age with a mean of 36 age, which tells us that the target users are adults.
# Area Income : The minimum users income in around 13k and the maximum users income around in 79k.
# Daily Internet Usage : The Daily Internet use from 104 min to 269 min.
# Clicked On Ad : The 50% of the ad were Clicked and 50% of the ads weren't Clicked by the user .

# %% [markdown]
# #  Find the Count Value of Gender?

# %%
gender_counts = ad["Gender"].value_counts()
print(gender_counts)
bars = plt.bar(gender_counts.index, gender_counts.values,color = ["black","blue"])
plt.xlabel("Gender")
plt.ylabel("Count")
legend_labels = ['Female', 'Male']
plt.legend(bars, legend_labels, title='Gender')
plt.title(" Gender Counts")
plt.show()
# Out:
# Female    525
# Male      484
# Name: Gender, dtype: int64

# %% [markdown]
# This simple bar plot visually shows the gender distribution, making it easy to understand that there are  males (525) more than females (484) in the dataset.

# %% [markdown]
# # Find the Count Value of Clicked on Ad?

# %%
x = ad["Clicked on Ad"].value_counts()
x
# Out:
# 1    506
# 0    503
# Name: Clicked on Ad, dtype: int64

# %%
bars = plt.bar(x.index,x.values,color = ["orange","purple"])
plt.xlabel("Clicked on Ad")
plt.ylabel("Count")
legend_labels = ["Click ad", 'Not_click Ad']
plt.legend(bars, legend_labels, title='Gender')
plt.title("Clicked on Ad counts")
plt.show()

# %% [markdown]
# This simple bar plot visually shows the Clicked on Ad distribution, making it easy to understand that there are Clicked on Ad (506) less than Not_clicked Ad (503) in the dataset.

# %% [markdown]
# # Find a Daily Internet Usage column to check a level of plot using histogram

# %%
plt.hist(ad["Daily Internet Usage"],facecolor = "peru", bins = 10, edgecolor = "blue")
plt.xlabel("Daily Internet Usage level")
plt.ylabel("frequency")
plt.title("DAILY INTERNET USAGE")
# Out:
# Text(0.5, 1.0, 'DAILY INTERNET USAGE')

# %% [markdown]
#  The X-axis shows the range of the values and Y-axis shows the number of values in the range.
#  The Daily Internet usage shows the users 200 - 225 minutes use internet.

# %% [markdown]
# # Find a Daily Time Spent on Site column to check a level of plot using histogram

# %%
plt.hist(ad["Daily Time Spent on Site"],color="r",edgecolor = "black")
plt.xlabel("Daily Time Spent on Site level")
plt.ylabel("frequency")
plt.title("DAILY TIME SPENT ON SITE")
# Out:
# Text(0.5, 1.0, 'DAILY TIME SPENT ON SITE')

# %% [markdown]
# In the Above diagram, the Daily Time Spent On Site 70 - 80 minutes highly users spent on site.

# %% [markdown]
# # Is there a Relationship Between Age and Daily Internet usage using a Scatter Plot?

# %%
plt.scatter(ad["Age"],ad["Daily Internet Usage"])
plt.xlabel("Age")
plt.ylabel("Daily Internet Usage")
plt.title("Scatter Plot of Age vs Distribution of Gender")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Distribution of Gender')

# %% [markdown]
# # Is there a Relationship Between Area Income and Daily Internet usage using a Scatter Plot?

# %%
plt.scatter(ad["Area Income"],ad["Daily Internet Usage"],color="orange")
plt.xlabel("Area Income")
plt.ylabel("Daily Internet Usage")
plt.title("Scatter Plot of Area Income vs Distribution of Gender")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Area Income vs Distribution of Gender')

# %% [markdown]
# # Is there a Relationship Between Age and Daily Internet usage those who Clicked Ad and not ?

# %%
not_clicked_ad = ad[ad["Clicked on Ad"]==0]

# %%
not_clicked_ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        68.95  35.0     61833.90                256.09
# 1                        68.95  31.0     68441.85                193.77
# 2                        69.47  26.0     59785.94                236.50
# 3                        74.15  29.0     54806.18                245.89
# 4                        68.37  35.0     73889.99                225.58
# ...                        ...   ...          ...                   ...
# 995                      76.44  28.0     59967.19                232.68
# 997                      89.71  48.0     51501.38                204.40
# 998                      70.96  31.0     55187.85                256.40
# 1002                     64.20  27.0     66200.96                227.63
# 1007                     55.55  19.0     41920.79                187.95
#
#                               Ad Topic Line            City  Gender  \
# ...

# %%
clicked_ad = ad[ad["Clicked on Ad"]==1]

# %%
clicked_ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7                        88.91  48.0     24593.33                131.76
# 10                       47.64  49.0     45632.51                122.02
# 12                       69.57  48.0     51636.92                113.12
# 14                       42.95  33.0     30976.00                143.56
# 15                       63.45  23.0     52182.23                140.64
# ...                        ...   ...          ...                   ...
# 1003                     43.70  28.0     63126.96                173.01
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line              City  Gender  \
# ...

# %%
plt.scatter(clicked_ad["Age"],clicked_ad["Daily Internet Usage"],color="green",label="clicked")

# %%
plt.scatter(not_clicked_ad["Age"],not_clicked_ad["Daily Internet Usage"],color="red",label="not_clicked")

# %%
plt.scatter(clicked_ad["Age"],clicked_ad["Daily Internet Usage"],color="green",label="clicked")
plt.scatter(not_clicked_ad["Age"],not_clicked_ad["Daily Internet Usage"],color="red",label="not_clicked")
plt.xlabel("Age")
plt.ylabel("internet")
plt.legend()

# %% [markdown]
# # Is there a Relationship Between Daily Time Spent on Site and Area Income those who Clicked ad and not ?

# %%
clicked_ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7                        88.91  48.0     24593.33                131.76
# 10                       47.64  49.0     45632.51                122.02
# 12                       69.57  48.0     51636.92                113.12
# 14                       42.95  33.0     30976.00                143.56
# 15                       63.45  23.0     52182.23                140.64
# ...                        ...   ...          ...                   ...
# 1003                     43.70  28.0     63126.96                173.01
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line              City  Gender  \
# ...

# %%
clicked_ad.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Gender', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
plt.scatter(clicked_ad["Daily Time Spent on Site"],clicked_ad["Area Income"],color="black",label="ad click")

# %%
not_clicked_ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        68.95  35.0     61833.90                256.09
# 1                        68.95  31.0     68441.85                193.77
# 2                        69.47  26.0     59785.94                236.50
# 3                        74.15  29.0     54806.18                245.89
# 4                        68.37  35.0     73889.99                225.58
# ...                        ...   ...          ...                   ...
# 995                      76.44  28.0     59967.19                232.68
# 997                      89.71  48.0     51501.38                204.40
# 998                      70.96  31.0     55187.85                256.40
# 1002                     64.20  27.0     66200.96                227.63
# 1007                     55.55  19.0     41920.79                187.95
#
#                               Ad Topic Line            City  Gender  \
# ...

# %%
plt.scatter(not_clicked_ad["Daily Time Spent on Site"],not_clicked_ad["Area Income"],color="r",label="ad click")

# %%
plt.scatter(clicked_ad["Daily Time Spent on Site"],clicked_ad["Area Income"],color="black",label="ad click")
plt.scatter(not_clicked_ad["Daily Time Spent on Site"],not_clicked_ad["Area Income"],color="r",label="ad click")
plt.xlabel("Daily Time Spent on Site")
plt.ylabel("Area Income")
plt.title("Scatter Plot for Daily Time spent on site vs Area Income")
plt.legend()

# %% [markdown]
# # 	What is the distribution of Area Income in the dataset?

# %%
area_mean =ad["Area Income"].mean()
area_mean
area_median = ad["Area Income"].median()
area_median
# Out:
# 56986.73

# %%
plt.figure(figsize=(8, 6))
plt.hist(ad["Area Income"],edgecolor='k',color="purple")
plt.axvline(area_mean, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {area_mean:.2f}')
plt.axvline(area_median, color='g', linestyle='dashed', linewidth=2, label=f'Median: {area_median}')
plt.legend()

# %% [markdown]
# Since median > mean, the data is left skewed, more data will be found towards right side of mean that right side percentage is 56% and left side percentage is 44%.

# %%
# 54907.63 < ad["Area Income"]
print((ad[ad["Area Income"]>54907.63].shape[0]/ad.shape[0])*100)
(ad[ad["Area Income"]<54907.63].shape[0]/ad.shape[0])*100
# Out:
# 55.89692765113974
# 44.10307234886026

# %% [markdown]
# # 	What is the distribution of Ages in the dataset?

# %%
age_mean = ad["Age"].mean()
age_mean
# Out:
# 35.94152626362735

# %%
age_median = ad["Age"].median()
age_median
# Out:
# 35.0

# %%
plt.figure(figsize=(10, 6))
plt.hist(ad["Age"],edgecolor='k',color="blue")
plt.axvline(age_mean, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {age_mean:.2f}')
plt.axvline(age_median, color='g', linestyle='dashed', linewidth=2, label=f'Median: {age_median}')
plt.legend()

# %% [markdown]
# Since mean > median, the data is Right skewed, more data will be found towards right side of mean that right side percentage is (47%) and left side percentage is (48%).

# %%
print((ad[ad["Age"]>35.94].shape[0]/ad.shape[0])*100)
(ad[ad["Age"]<35].shape[0]/ad.shape[0])*100
# Out:
# 47.472745292368685
# 48.66204162537166

# %% [markdown]
# # 	What is the average age of users who clicked on the ad?

# %%
# Filter the dataset to include only users who clicked on the ad
clicked_users = ad[ad['Clicked on Ad'] == 1]

# Calculate the average age of these users
average_age = clicked_users['Age'].mean()

print("Average age of users who clicked on the ad:", average_age)
# Out:
# Average age of users who clicked on the ad: 40.205533596837945

# %% [markdown]
# The average age of users who clicked on the ad was approximately 40.21 years.

# %% [markdown]
# # 	How many users clicked on the advertisement? What percentage of the total is this?

# %%
clicked = ad[ad["Clicked on Ad"]==1]
clicked
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7                        88.91  48.0     24593.33                131.76
# 10                       47.64  49.0     45632.51                122.02
# 12                       69.57  48.0     51636.92                113.12
# 14                       42.95  33.0     30976.00                143.56
# 15                       63.45  23.0     52182.23                140.64
# ...                        ...   ...          ...                   ...
# 1003                     43.70  28.0     63126.96                173.01
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line              City  Gender  \
# ...

# %%
percent_clicked = (clicked.shape[0]/1009)*100

# %%
percent_clicked
# Out:
# 50.14866204162537

# %% [markdown]
# In the dataset comprising 1009 records, precisely 506 users were observed to have clicked on the advertisement, resulting in a total click-through rate of 50%. Equally noteworthy is the fact that an equivalent percentage of users, 50%, did not click on the advertisement.

# %% [markdown]
# # 	Is there a particular ad topic line that receives more clicks than others?

# %%
# Group the data by ad_topic_line and calculate the mean click-through rate (CTR)
ctr_by_topic = ad.groupby('Ad Topic Line')['Clicked on Ad'].mean().reset_index()
ctr_by_topic
# Out:
#                                Ad Topic Line  Clicked on Ad
# 0          Adaptive 24hour Graphic Interface            0.0
# 1             Adaptive asynchronous attitude            1.0
# 2     Adaptive context-sensitive application            1.0
# 3    Adaptive contextually-based methodology            1.0
# 4       Adaptive demand-driven knowledgebase            1.0
# ..                                       ...            ...
# 995     Visionary client-driven installation            0.0
# 996  Visionary maximized process improvement            1.0
# 997   Visionary mission-critical application            1.0
# 998         Visionary multi-tasking alliance            0.0
# 999             Visionary reciprocal circuit            0.0
#
# [1000 rows x 2 columns]

# %%
# Sort the results in descending order to find the most-clicked topics
sorted_ctr_by_topic =ctr_by_topic.sort_values(by='Clicked on Ad', ascending=False)
sorted_ctr_by_topic
# Out:
#                               Ad Topic Line  Clicked on Ad
# 500     Networked asymmetric infrastructure            1.0
# 402   Integrated coherent pricing structure            1.0
# 394         Innovative homogeneous alliance            1.0
# 395           Innovative interactive portal            1.0
# 396          Innovative maximized groupware            1.0
# ..                                      ...            ...
# 450      Mandatory dedicated data-warehouse            0.0
# 454      Mandatory homogeneous architecture            0.0
# 455               Monitored 24/7 moratorium            0.0
# 456  Monitored content-based implementation            0.0
# 999            Visionary reciprocal circuit            0.0
#
# [1000 rows x 2 columns]

# %%
# Print the topics with the highest CTR
print("Ad Topic Lines with the Highest Click-Through Rates:")
print(sorted_ctr_by_topic.head())
# Out:
# Ad Topic Lines with the Highest Click-Through Rates:
#                              Ad Topic Line  Clicked on Ad
# 500    Networked asymmetric infrastructure            1.0
# 402  Integrated coherent pricing structure            1.0
# 394        Innovative homogeneous alliance            1.0
# 395          Innovative interactive portal            1.0
# 396         Innovative maximized groupware            1.0

# %%
head_of_sorted_topic  = sorted_ctr_by_topic.head()
head_of_sorted_topic
# Out:
#                              Ad Topic Line  Clicked on Ad
# 500    Networked asymmetric infrastructure            1.0
# 402  Integrated coherent pricing structure            1.0
# 394        Innovative homogeneous alliance            1.0
# 395          Innovative interactive portal            1.0
# 396         Innovative maximized groupware            1.0

# %%
# Plot the bar diagram
plt.figure(figsize=(12, 6))
plt.bar(head_of_sorted_topic['Ad Topic Line'], head_of_sorted_topic['Clicked on Ad'],color=["r","b","black","orange","purple"])
plt.xticks(rotation=90)
plt.xlabel('Ad Topic Line',size=15)
plt.ylabel('Click-Through Rate (CTR)',size = 15)
plt.title('Click-Through Rate by Ad Topic Line',size = 20)
plt.show()

# %% [markdown]
# IIn the above diagram, it is evident that certain advertisement topic lines,
# such as :
#     Networked asymmetric infrastructure
#     Integrated coherent pricing structure
#     Innovative homogeneous alliance
#     Innovative interactive portal
#     Innovative maximized groupware
# Have consistently Higher Click-through rates from users over time.

# %% [markdown]
# # 	How does the gender distribution differ between those who clicked on the ad and those who didn't?

# %%
gender_distribution = ad.groupby(["Gender","Clicked on Ad"]).size().unstack()

# %%
gender_distribution
# Out:
# Clicked on Ad    0    1
# Gender
# Female         252  273
# Male           251  233

# %%
plt.figure(figsize=(8, 6))
stack_bar = gender_distribution.plot(kind="bar",stacked=True)
stack_bar
plt.xlabel('Clicked on Ad')
plt.ylabel('Count')
plt.title('Gender Distribution by Clicked on Ad')
plt.show()

# %% [markdown]
# In this plot, the stacked bar chart illustrates the gender distribution among individuals who both clicked on the Ad and those who didn't click on the Ad.

# %% [markdown]
# # Is there a relationship between daily time spent on the site and Daily Internet usage those clicking on the ad?

# %%
clicked_ad = ad[ad["Clicked on Ad"]==1]
clicked_ad
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7                        88.91  48.0     24593.33                131.76
# 10                       47.64  49.0     45632.51                122.02
# 12                       69.57  48.0     51636.92                113.12
# 14                       42.95  33.0     30976.00                143.56
# 15                       63.45  23.0     52182.23                140.64
# ...                        ...   ...          ...                   ...
# 1003                     43.70  28.0     63126.96                173.01
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line              City  Gender  \
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(clicked_ad["Daily Time Spent on Site"],clicked_ad["Daily Internet Usage"],label="Clicked on Ad")
plt.xlabel('Daily Time Spent on Site (minutes)')
plt.ylabel('Clicked on Ad')
plt.title('Relationship Between Daily Time Spent and Clicking on Ad')
plt.legend()
plt.show()

# %% [markdown]
# Interpretation:
# In the scatter plot, we can observe a generally positive correlation between daily time spent on the site and daily internet usage for those clicking on the ad. As daily time spent on the site increases, there is a tendency for daily internet usage to also increase. This suggests that users who spend more time on the site tend to use more internet data when clicking on ads.
#
# However, it's important to note that the relationship is not perfectly linear, as there is some spread of data points. Other factors may also influence daily internet usage, and this scatter plot provides an initial visual exploration of the relationship. Further statistical analysis, such as calculating correlation coefficients, could provide a more precise assessment of the strength and direction of the relationship.

# %% [markdown]
# # 	Which country has the highest daily time spent on the site on average?

# %%
data = ad[["Daily Time Spent on Site",'Country']]
data
# Out:
#       Daily Time Spent on Site                 Country
# 0                        68.95                 Tunisia
# 1                        68.95                   Nauru
# 2                        69.47              San Marino
# 3                        74.15                   Italy
# 4                        68.37                 Iceland
# ...                        ...                     ...
# 1004                     72.97                 Lebanon
# 1005                     51.30  Bosnia and Herzegovina
# 1006                     51.63                Mongolia
# 1007                     55.55               Guatemala
# 1008                     45.01                  Brazil
#
# [1009 rows x 2 columns]

# %%
# Group the data by 'Country' and calculate the average time spent
average_time_per_country = data.groupby('Country')['Daily Time Spent on Site'].mean()
average_time_per_country
# Out:
# Country
# Afghanistan          64.782500
# Albania              63.371429
# Algeria              66.011667
# American Samoa       63.810000
# Andorra              49.805000
#                        ...
# Wallis and Futuna    71.465000
# Western Sahara       60.132857
# Yemen                66.850000
# Zambia               60.720000
# Zimbabwe             62.685000
# Name: Daily Time Spent on Site, Length: 237, dtype: float64

# %%
# Find the country with the highest average time spent
highest_average_time_country = average_time_per_country.idxmax()
highest_average_time_country
# Out:
# 'Lesotho'

# %%
highest_average_time = average_time_per_country.max()
highest_average_time
# Out:
# 89.8

# %%
print(f"The country with the highest average time spent is {highest_average_time_country} with an average of {highest_average_time} minutes.")
# Out:
# The country with the highest average time spent is Lesotho with an average of 89.8 minutes.

# %% [markdown]
# On average, users from the Lesotho country spend the highest amount of daily time on the site compared to other countries in the dataset. The average daily time spent on the site by users in the Lesotho country is approximately 1 hours and 29.8 minutes making it the country with the highest average engagement.

# %% [markdown]
# # 	How does the average age vary by country?

# %%
data = ad[["Age","Country"]]
data
# Out:
#        Age                 Country
# 0     35.0                 Tunisia
# 1     31.0                   Nauru
# 2     26.0              San Marino
# 3     29.0                   Italy
# 4     35.0                 Iceland
# ...    ...                     ...
# 1004  30.0                 Lebanon
# 1005  45.0  Bosnia and Herzegovina
# 1006  51.0                Mongolia
# 1007  19.0               Guatemala
# 1008  26.0                  Brazil
#
# [1009 rows x 2 columns]

# %%
avg_age_per_country = data.groupby("Country")["Age"].mean()
print("The Average Age by Country:")
avg_age_per_country
# Out:
# The Average Age by Country:
# Country
# Afghanistan          42.125000
# Albania              30.857143
# Algeria              30.000000
# American Samoa       36.800000
# Andorra              30.000000
#                        ...
# Wallis and Futuna    33.500000
# Western Sahara       40.000000
# Yemen                35.000000
# Zambia               40.500000
# Zimbabwe             32.500000
# Name: Age, Length: 237, dtype: float64

# %% [markdown]
# Afghanistan Country has the highest average age among all countries in the dataset, with an average age of 42 years.
# Zimbabwe Country has the lowest average age of 32 years, suggesting a younger population compared to the other countries.

# %% [markdown]
# # Using a Pie chart to Predict the percentage of Clicked on Ad

# %%
clicked_ad_counts = ad["Clicked on Ad"].value_counts()
clicked_ad_counts
# Out:
# 1    506
# 0    503
# Name: Clicked on Ad, dtype: int64

# %%
labels = ["clicked Ad","Not clicked Ad"]
plt.pie(clicked_ad_counts,labels=clicked_ad_counts.index,autopct="%1.1f%%")
plt.legend(labels,loc = "best")
plt.figure(figsize=(18,8))

# %% [markdown]
# In our Ad campaign analysis, we created a pie chart to visualize the distribution of clicks on the ad. The chart reveals the following insights:
#
# Clicked on Ad: The pie chart illustrates the proportion of users who clicked on the ad compared to those who did not. It shows that (50.1%) of users clicked on the ad, indicating the effectiveness of our campaign in capturing user engagement.
#
# Not Clicked on Ad: The remaining percentage (100% - 50.1%) represents users who did not click on the ad.

# %% [markdown]
# # Targeting a male audience, which country is expected to yield the highest number of ad clicks?

# %%
df = ad[ad["Gender"]=="Male"]
df
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 1                        69.47  31.0     68441.85                193.77
# 3                        74.15  29.0     54806.18                245.89
# 5                        59.99  23.0     59761.56                226.74
# 7                        74.53  48.0     24593.33                131.76
# 8                        74.53  30.0     55642.32                221.51
# ...                        ...   ...          ...                   ...
# 1000                     38.96  38.0     66193.81                140.67
# 1002                     64.20  27.0     66200.96                227.63
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
#
#                                Ad Topic Line              City Gender  \
# ...

# %%
x=df.groupby("Country")["Clicked on Ad"].max()
print(x)
# Out:
# Country
# Afghanistan          1
# Albania              1
# Algeria              0
# American Samoa       1
# Andorra              1
#                     ..
# Venezuela            1
# Wallis and Futuna    1
# Western Sahara       1
# Zambia               1
# Zimbabwe             1
# Name: Clicked on Ad, Length: 215, dtype: int64

# %%
x=df.groupby("Country")["Clicked on Ad"].value_counts()
print(x)
# Out:
# Country         Clicked on Ad
# Afghanistan     0                1
#                 1                1
# Albania         1                2
#                 0                1
# Algeria         0                1
#                                 ..
# Western Sahara  1                1
# Zambia          1                2
#                 0                1
# Zimbabwe        0                1
#                 1                1
# Name: Clicked on Ad, Length: 315, dtype: int64

# %%
y = x.groupby("Country").idxmax()
y
# Out:
# Country
# Afghanistan                (Afghanistan, 0)
# Albania                        (Albania, 1)
# Algeria                        (Algeria, 0)
# American Samoa          (American Samoa, 1)
# Andorra                        (Andorra, 1)
#                               ...
# Venezuela                    (Venezuela, 1)
# Wallis and Futuna    (Wallis and Futuna, 0)
# Western Sahara          (Western Sahara, 0)
# Zambia                          (Zambia, 1)
# Zimbabwe                      (Zimbabwe, 0)
# Name: Clicked on Ad, Length: 215, dtype: object

# %% [markdown]
# In the results, It appears that in the case of the male-only audience,there shows which country more time clicked Ad or not

# %% [markdown]
# # What are the top 5 'Ad Topic Lines' with the most clicks?

# %%
df1 = ad[ad["Clicked on Ad"]==1]
df1
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7                        74.53  48.0     24593.33                131.76
# 10                       47.64  49.0     45632.51                122.02
# 12                       69.57  48.0     51636.92                113.12
# 14                       42.95  33.0     30976.00                143.56
# 15                       63.45  23.0     52182.23                140.64
# ...                        ...   ...          ...                   ...
# 1003                     43.70  28.0     63126.96                173.01
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
# 1008                     45.01  26.0     29875.80                178.35
#
#                               Ad Topic Line              City  Gender  \
# ...

# %%
top_5= df1["Ad Topic Line"].value_counts()
top_5
# Out:
# Quality-focused zero-defect data-warehouse    2
# Virtual 5thgeneration emulation               2
# Stand-alone tangible moderator                2
# Proactive non-volatile encryption             2
# Networked local secured line                  2
#                                              ..
# Horizontal national architecture              1
# Upgradable even-keeled challenge              1
# Extended interactive model                    1
# Proactive context-sensitive project           1
# Expanded intangible solution                  1
# Name: Ad Topic Line, Length: 500, dtype: int64

# %%
print("The Top 5 Ad Topic Lines are :")
print(top_5.head(5))
# Out:
# The Top 5 Ad Topic Lines are :
# Quality-focused zero-defect data-warehouse    2
# Virtual 5thgeneration emulation               2
# Stand-alone tangible moderator                2
# Proactive non-volatile encryption             2
# Networked local secured line                  2
# Name: Ad Topic Line, dtype: int64

# %% [markdown]
# Certainly, here are the top 5 'Ad Topic Lines' with the most clicks:
#
# "Quality-focused zero-defect data-warehouse"
# "Virtual 5th generation emulation"
# "Stand-alone tangible moderator"
# "Proactive non-volatile encryption"
# "Networked local secured line"
# These 'Ad Topic Lines' received the most clicks, indicating that they were particularly effective in attracting user engagement or interest in the dataset.

# %% [markdown]
# # How does the 'Age' distribution differ between genders ?

# %%
male = ad[ad["Gender"]=="Male"]
male
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 1                        69.47  31.0     68441.85                193.77
# 3                        74.15  29.0     54806.18                245.89
# 5                        59.99  23.0     59761.56                226.74
# 7                        74.53  48.0     24593.33                131.76
# 8                        74.53  30.0     55642.32                221.51
# ...                        ...   ...          ...                   ...
# 1000                     38.96  38.0     66193.81                140.67
# 1002                     64.20  27.0     66200.96                227.63
# 1004                     72.97  30.0     71384.57                208.58
# 1005                     51.30  45.0     67782.17                134.42
# 1006                     51.63  51.0     42415.72                120.37
#
#                                Ad Topic Line              City Gender  \
# ...

# %%
female = ad[ad["Gender"]=="Female"]
female
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        68.95  35.0     61833.90                256.09
# 2                        69.47  26.0     59785.94                236.50
# 4                        68.37  35.0     73889.99                225.58
# 6                        88.91  33.0     53852.85                208.36
# 10                       47.64  49.0     45632.51                122.02
# ...                        ...   ...          ...                   ...
# 998                      70.96  31.0     55187.85                256.40
# 1001                     69.17  40.0     66193.81                123.62
# 1003                     43.70  28.0     63126.96                173.01
# 1007                     55.55  19.0     41920.79                187.95
# 1008                     45.01  26.0     29875.80                178.35
#
#                              Ad Topic Line             City  Gender  \
# ...

# %%
plt.hist(male["Age"],bins=10,edgecolor="r",alpha=0.8,label="Male")
plt.hist(female["Age"],bins=10,edgecolor="g",alpha=0.8,label="female")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution by Gender')
plt.legend()
plt.show()

# %% [markdown]
# This difference in the age distribution between genders suggests that there may be variations in the age demographics or behaviors of males and females within our dataset.
